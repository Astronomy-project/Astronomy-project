# %% [markdown]
# # Librerias

# %%
import read_data as read
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use('dark_background')
# %matplotlib widget
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Datos

# %%
read.data()
# Out:
#                                        id   source_id  \
# 0    0000374f-8986-535a-9de2-6c1847d5c907      136101
# 1    000037ed-d09d-57c4-9ccf-906521333f35   AP2945282
# 2    00008a95-cf2c-567e-be66-4c309074e480      421359
# 3    0000955a-fbf6-5867-a847-7ebdc8c5af7d  AP41132326
# 4    0000b25b-1f49-5cbb-bed3-5124db6e1a6e  AP27759928
# ..                                    ...         ...
# 580  002ff72b-4314-505c-a76a-05121f940bba      257253
# 581  0030004d-f45c-56c8-afaa-2453b70ea739  AP24584582
# 582  00302619-d8d4-5681-bd4d-6fbd9c2343d5      115227
# 583  0030295a-b890-576f-96fe-b9b265bca3e7   AP2959364
# 584  0030506e-cb7f-5354-8c44-40f9b57814dd      365147
#
#                       asassn_name    raj2000   dej2000          l         b  \
# 0    ASASSN-V J221121.85-290944.6  332.84103 -29.16240   20.01945 -54.82383
# 1    ASASSN-V J011050.90+480630.0   17.71208  48.10833  126.27871 -14.63724
# 2    ASASSN-V J171856.79-434355.6  259.73664 -43.73212  344.67875  -3.59326
# ...

# %%
read.data().keys()
# Out:
# Index(['id', 'source_id', 'asassn_name', 'raj2000', 'dej2000', 'l', 'b',
#        'mean_vmag', 'amplitude', 'variable_type', 'lksl_statistic',
#        'rfr_score', 'epoch_hjd', 'e_b_v', 'reference', 'periodic',
#        'asassn_discovery', 'created_at', 'updated_at'],
#       dtype='object')

# %%
example=read.data().iloc[0]
print(example)
# Out:
# id                       0000374f-8986-535a-9de2-6c1847d5c907
# source_id                                              136101
# asassn_name                      ASASSN-V J221121.85-290944.6
# raj2000                                             332.84103
# dej2000                                              -29.1624
# l                                                    20.01945
# b                                                   -54.82383
# mean_vmag                                               13.56
# amplitude                                                 0.4
# variable_type                                              EW
# lksl_statistic                                           0.07
# rfr_score                                                0.97
# epoch_hjd                                       2457942.89757
# e_b_v                                                   0.016
# reference           The ASAS-SN Catalog of Variable Stars: II
# ...

# %% [markdown]
# # Análisis de Fourier

# %%
pd.read_csv('Stars 2022-05-21 20_14.csv')
# Out:
#                                        id  \
# 0    0324d9ca-5efb-50e8-abcc-45d204e76fa4
# 1    032983a4-6650-5fcf-ba1f-4cf4333427cd
# 2    04e34a45-1bb1-5e90-ab4e-d34d6143203d
# 3    052007ea-7344-5062-9827-d0366f41f51a
# 4    0b43da19-be40-5faa-90cb-5c61b411b97f
# ..                                    ...
# 232  f9adb435-c6cf-53f0-86a1-49bd95d94d6a
# 233  fa46c27e-407f-5f08-b621-3742f6e7849f
# 234  fe193783-5f45-55be-a385-1b8da969c8cd
# 235  fe68ef63-95c6-5357-bab2-f1e92b95bae5
# 236  febcfcdd-bdf4-51ec-8527-bc6992856e11
#
#                                   star_id           hjd camera     mag  \
# 0    885aae98-102b-5794-a60a-e2c0b55ec984  2.458037e+06     bb  15.013
# 1    885aae98-102b-5794-a60a-e2c0b55ec984  2.457587e+06     bb  14.810
# 2    885aae98-102b-5794-a60a-e2c0b55ec984  2.457329e+06     bb  14.940
# 3    885aae98-102b-5794-a60a-e2c0b55ec984  2.456788e+06     bb  14.869
# 4    885aae98-102b-5794-a60a-e2c0b55ec984  2.457367e+06     bb  14.938
# ...

# %%
pd.read_csv('Stars 2022-05-21 20_14.csv').keys()
# Out:
# Index(['id', 'star_id', 'hjd', 'camera', 'mag', 'mag_err', 'flux', 'flux_err',
#        'created_at', 'updated_at'],
#       dtype='object')

# %%
datos=pd.read_csv('Stars 2022-05-21 20_14.csv')
plt.errorbar(datos['hjd'],datos['mag'],yerr=datos['mag_err'],fmt="o")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
