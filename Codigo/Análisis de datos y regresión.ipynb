# %% [markdown]
# # Librerias

# %%
import matplotlib.pyplot as plt
import pandas as pd
from gatspy.periodic import LombScargleFast
from scipy.optimize import curve_fit
import Clasification_Algorithm as A
import scrip_for_total_clasification as S
from os import listdir
import os
plt.style.use('dark_background')
# %matplotlib widget
# %config InlineBackend.figure_format = 'retina'
import Clasification_Algorithm as C

# %% [markdown]
# # Dataset Clasificactions of the ASAS-SN

# %%
os.chdir('subset of dataset of all stars/')

# %%
C.graphic_information('ASASSN-VJ000122.81-194327.0.dat')
# Out:
# Finding optimal frequency:
#  - Estimated peak width = 0.00342
#  - Using 5 steps per peak; omega_step = 0.000685
#  - User-specified period range:  0.1 to 1e+03
#  - Computing periods at 91743 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Finding optimal frequency:
#  - Estimated peak width = 0.00342
#  - Using 5 steps per peak; omega_step = 0.000685
#  - User-specified period range:  0.1 to 1e+03
#  - Computing periods at 91743 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# period ajust=  0.21883670732331875
# amplitude ajust =  1.6685000000000008
# 'Thanks'
