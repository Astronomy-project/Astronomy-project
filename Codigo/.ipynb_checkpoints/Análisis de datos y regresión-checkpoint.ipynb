# %% [markdown]
# # Librerias

# %%
import read_data as read
import matplotlib.pyplot as plt
import pandas as pd
from gatspy.periodic import LombScargleFast
from scipy.optimize import curve_fit
import Clasification_Algorithm as A
from os import listdir
import os
plt.style.use('dark_background')
# %matplotlib widget
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Clasificactions

# %%
A.graphic_information('Stars 2022-05-22 19_37.csv')
# Out:
# Finding optimal frequency:
#  - Estimated peak width = 0.00251
#  - Using 5 steps per peak; omega_step = 0.000502
#  - User-specified period range:  0.1 to 1e+03
#  - Computing periods at 125140 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Finding optimal frequency:
#  - Estimated peak width = 0.00251
#  - Using 5 steps per peak; omega_step = 0.000502
#  - User-specified period range:  0.1 to 1e+03
#  - Computing periods at 125140 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# period ajust=  0.9969322157583032
# amplitude ajust =  0.15550000000000086

# %% [markdown]
# # Put the directory in the data
